# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\user\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
heist=pd.read_excel("D:\money heist - all seasons.xlsx")

# %%
heist
# Out:
#     Season   Episode                               Name     On Air  Year  \
# 0         1         1              Efectuar lo acordado 2017-05-02  2017
# 1         1         2              Imprudencias letales 2017-05-09  2017
# 2         1         3                           Misfire 2017-05-16  2017
# 3         1         4                  Caballo de Troya 2017-05-23  2017
# 4         1         5              El día de la marmota 2017-05-30  2017
# 5         1         6             La cálida Guerra Fría 2017-06-06  2017
# 6         1         7         Refrigerada inestabilidad 2018-06-13  2017
# 7         1         8                 Tú lo has buscado 2019-06-20  2017
# 8         1         9       El que la sigue la consigue 2020-06-27  2017
# 9         2         1          Se acabaron las máscaras 2017-10-16  2017
# 10        2         2                La cabeza del plan 2017-10-23  2017
# 11        2         3              Cuestión de eficacia 2017-11-02  2017
# ...

# %%
heist.columns
# Out:
# Index(['Season ', 'Episode ', 'Name', 'On Air', 'Year', 'IMDB',
#        'Watch Time (minutes)', 'Summary'],
#       dtype='object')

# %%
heist.shape#36 columns and 8 rows
# Out:
# (36, 8)

# %%
heist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Season                36 non-null     int64
#  1   Episode               36 non-null     int64
#  2   Name                  36 non-null     object
#  3   On Air                36 non-null     datetime64[ns]
#  4   Year                  36 non-null     int64
#  5   IMDB                  36 non-null     float64
#  6   Watch Time (minutes)  36 non-null     int64
#  7   Summary               36 non-null     object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(2)
# memory usage: 2.4+ KB

# %%
heist.dtypes
# Out:
# Season                           int64
# Episode                          int64
# Name                            object
# On Air                  datetime64[ns]
# Year                             int64
# IMDB                           float64
# Watch Time (minutes)             int64
# Summary                         object
# dtype: object

# %%
heist.describe()
# Out:
#          Season    Episode                On Air         Year       IMDB  \
# count  36.000000  36.000000                   36    36.000000  36.000000
# mean    2.833333   4.250000  2019-07-07 15:20:00  2018.666667   8.188889
# min     1.000000   1.000000  2017-05-02 00:00:00  2017.000000   7.100000
# 25%     1.750000   2.000000  2017-11-07 06:00:00  2017.000000   7.775000
# 50%     3.000000   4.000000  2019-07-19 00:00:00  2019.000000   8.300000
# 75%     4.000000   6.000000  2020-07-02 12:00:00  2020.000000   8.425000
# max     5.000000   9.000000  2022-04-03 00:00:00  2021.000000   9.500000
# std     1.404076   2.322253                  NaN     1.549193   0.588838
#
#        Watch Time (minutes)
# count             36.000000
# mean              48.222222
# min               41.000000
# 25%               43.000000
# 50%               47.500000
# 75%               52.000000
# max               61.000000
# std                5.361829

# %%
heist.head()
# Out:
#    Season   Episode                   Name     On Air  Year  IMDB  \
# 0        1         1  Efectuar lo acordado 2017-05-02  2017   8.4
# 1        1         2  Imprudencias letales 2017-05-09  2017   8.4
# 2        1         3               Misfire 2017-05-16  2017   8.2
# 3        1         4      Caballo de Troya 2017-05-23  2017   8.3
# 4        1         5  El día de la marmota 2017-05-30  2017   8.4
#
#    Watch Time (minutes)                                            Summary
# 0                    47  The Professor recruits a young female robber a...
# 1                    41  Hostage negotiator Raquel makes initial contac...
# 2                    50  Police grab an image of the face of one of the...
# 3                    51  Raquel is adversely affected by a personal cri...
# 4                    42  A sudden development in the investigation and ...

# %%
heist.tail()
# Out:
#     Season   Episode                               Name     On Air  Year  \
# 31        5         1               The End of the Road 2021-09-03  2021
# 32        5         2  Do You Believe in Reincarnation? 2021-09-03  2021
# 33        5         3  Welcome to the Spectacle of Life 2021-09-03  2021
# 34        5         4              Your Place in Heaven 2021-09-03  2021
# 35        5         5                   Live Many Lives 2021-09-03  2021
#
#     IMDB  Watch Time (minutes)  \
# 31   7.5                    49
# 32   7.1                    52
# 33   7.3                    50
# 34   7.8                    52
# 35   8.4                    55
#
#                                               Summary
# 31  The Professor faces off with Sierra as Tamayo ...
# 32  Arturo seizes an opportunity to fight back whi...
# 33  A betrayal and an emergency both catch Sierra ...
# 34  With Helsinki's life in danger, the thieves mo...
# 35  While surrounded by gunfire and trapped in the...

# %%
heist.isnull().sum()
# Out:
# Season                  0
# Episode                 0
# Name                    0
# On Air                  0
# Year                    0
# IMDB                    0
# Watch Time (minutes)    0
# Summary                 0
# dtype: int64

# %%
heist['Summary'][2]#is retrieving the value in the 'Summary' column at the third row of the DataFrame
# Out:
# 'Police grab an image of the face of one of the robbers. Raquel is suspicious of the gentleman she meets at a bar.'

# %%
heist
# Out:
#     Season   Episode                               Name     On Air  Year  \
# 0         1         1              Efectuar lo acordado 2017-05-02  2017
# 1         1         2              Imprudencias letales 2017-05-09  2017
# 2         1         3                           Misfire 2017-05-16  2017
# 3         1         4                  Caballo de Troya 2017-05-23  2017
# 4         1         5              El día de la marmota 2017-05-30  2017
# 5         1         6             La cálida Guerra Fría 2017-06-06  2017
# 6         1         7         Refrigerada inestabilidad 2018-06-13  2017
# 7         1         8                 Tú lo has buscado 2019-06-20  2017
# 8         1         9       El que la sigue la consigue 2020-06-27  2017
# 9         2         1          Se acabaron las máscaras 2017-10-16  2017
# 10        2         2                La cabeza del plan 2017-10-23  2017
# 11        2         3              Cuestión de eficacia 2017-11-02  2017
# ...

# %%
heist.iloc[:,6:7].plot.hist()#resulting DataFrame will contain only the data from the 7th column of heist.
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# h box plot visually represents the distribution of the IMDb ratings. It includes key statistical measures such as the median, quartiles, and potential outliers.

# %%
heist['IMDB'].plot.box()
# Out:
# <AxesSubplot:>

# %%
heist['IMDB'].nlargest() #top rated IMDB
# Out:
# 22    9.5
# 14    9.4
# 11    8.8
# 12    8.8
# 13    8.8
# Name: IMDB, dtype: float64

# %%
heist[heist['IMDB']==9.5]# highist rating season
# Out:
#     Season   Episode     Name     On Air  Year  IMDB  Watch Time (minutes)  \
# 22        3         8  Astray 2021-07-19  2019   9.5                    60
#
#                                               Summary
# 22  Tokyo attempts to drown her sorrows. Sierra us...

# %%
summ=heist[heist['IMDB']==9.5]

# %% [markdown]
# -summary or text data located in the 'Summary' column for the 23rd entry (since Python uses 0-based indexing) in the DataFrame summ.

# %%
summ['Summary'][22]# a Series containing text or summary information for each entry in the DataFrame.
# Out:
# 'Tokyo attempts to drown her sorrows. Sierra uses personal tactics to target a vulnerable Nairobi, while Suárez continues to hunt down Raquel.'

# %%
heist[heist['IMDB']==heist['IMDB'].min()]
# Out:
#     Season   Episode                               Name     On Air  Year  \
# 25        4         3                    Anatomy Lesson 2020-04-03  2020
# 32        5         2  Do You Believe in Reincarnation? 2021-09-03  2021
#
#     IMDB  Watch Time (minutes)  \
# 25   7.1                    43
# 32   7.1                    52
#
#                                               Summary
# 25  The Professor's mole attempts to pass along hi...
# 32  Arturo seizes an opportunity to fight back whi...

# %% [markdown]
# - is filtering the DataFrame heist to select rows where the value in the 'IMDB' column is equal to the minimum IMDb score in that column.

# %%
heist.describe().T
# Out:
#                      count                 mean                  min  \
# Season                36.0             2.833333                  1.0
# Episode               36.0                 4.25                  1.0
# On Air                  36  2019-07-07 15:20:00  2017-05-02 00:00:00
# Year                  36.0          2018.666667               2017.0
# IMDB                  36.0             8.188889                  7.1
# Watch Time (minutes)  36.0            48.222222                 41.0
#
#                                       25%                  50%  \
# Season                               1.75                  3.0
# Episode                               2.0                  4.0
# On Air                2017-11-07 06:00:00  2019-07-19 00:00:00
# Year                               2017.0               2019.0
# IMDB                                7.775                  8.3
# Watch Time (minutes)                 43.0                 47.5
#
# ...

# %% [markdown]
# -provides a transposed summary statistics DataFrame where each row corresponds to a numerical column in the original DataFrame,

# %%
heist['Season '].unique()
# Out:
# array([1, 2, 3, 4, 5], dtype=int64)

# %%
heist['Season '].value_counts()#number of episode
# Out:
# Season
# 1    9
# 3    8
# 4    8
# 2    6
# 5    5
# Name: count, dtype: int64

# %%
df=heist.groupby('Season ').count().loc[:,:'Episode ']
df
# Out:
#          Episode
# Season
# 1               9
# 2               6
# 3               8
# 4               8
# 5               5

# %% [markdown]
# -ntains the count of rows for each unique value in the 'Season' column, and it includes columns from the beginning of the DataFrame up to the 'Episode ' column.

# %%
sns.barplot(df,x=df['Episode '],y=df.index,color='red')
plt.show()

# %%
df.plot(kind='barh',color='green',title='Season by Episode')
# Out:
# <AxesSubplot:title={'center':'Season by Episode'}, ylabel='Season '>

# %%
sns.countplot(data=heist,x='Year',palette='rainbow')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='Name',y='Watch Time (minutes)',data=heist.sort_values('Watch Time (minutes)',ascending=False),hue='Year',alpha=0.8,width=2)
plt.title('Episodes with Featured Time')
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x='Year',y='Watch Time (minutes)',data=heist,hue='Season ')
plt.title('Watch time over the years')
plt.show()
